# %% [markdown]
# #### Baby project
# This is just an experiment

# %%
print(2*3)

3+4
# Out:
# 6
# 7

# %% [markdown]
# #### Ejemplo 2
# jadounasid as

# %%
#comentario

# %% [markdown]
# #### Ejemplo 3
# que pasa si solo pongo un #
